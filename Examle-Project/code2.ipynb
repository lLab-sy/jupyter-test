# %%
# with pip
# %pip install pandas
# %pip install numpy
# %pip install matplotlib
# Out:
# Requirement already satisfied: pandas in /Users/ballsarin/anaconda3/lib/python3.11/site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ballsarin/anaconda3/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/ballsarin/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/ballsarin/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /Users/ballsarin/anaconda3/lib/python3.11/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in /Users/ballsarin/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in /Users/ballsarin/anaconda3/lib/python3.11/site-packages (1.24.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in /Users/ballsarin/anaconda3/lib/python3.11/site-packages (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/ballsarin/anaconda3/lib/python3.11/site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/ballsarin/anaconda3/lib/python3.11/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/ballsarin/anaconda3/lib/python3.11/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/ballsarin/anaconda3/lib/python3.11/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /Users/ballsarin/anaconda3/lib/python3.11/site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /Users/ballsarin/anaconda3/lib/python3.11/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/ballsarin/anaconda3/lib/python3.11/site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/ballsarin/anaconda3/lib/python3.11/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/ballsarin/anaconda3/lib/python3.11/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/ballsarin/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# with import
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('./statsfinal.csv')

# %% [markdown]
# Qustion (2) Out of all four products , which product has seen the highest sales in all the given years?

# %%
years = [int(date[-4:]) for date in data['Date']]
data['Year'] = years
data.head(5)
data2 = pd.DataFrame(columns=data.columns[2:-1])
data2['Year'] = []
# data2.head()
for year in data['Year'].unique():
    newRow = {'Year': year}
    for col in data.columns[2:-1]:
        if col[0] == 'Q':
            newRow[col] = np.median(data[data['Year'] == year][col]) 
        else:
            newRow[col] = np.mean(data[data['Year'] == year][col])
        # newRow[col] = np.sum(data_year[data_year['Year'] == year][col])
    data2.loc[len(data2)] = newRow
data2
# Out:
#       Q-P1    Q-P2    Q-P3    Q-P4          S-P1          S-P2          S-P3  \
# 0   3914.0  2164.0  3323.0  1130.0  12805.711791  13667.589055  16991.430348
# 1   3867.0  2084.5  3280.5  1168.0  12502.628049  13092.657363  17285.883901
# 2   4163.0  2044.0  3149.0  1163.0  13174.371543  13444.939339  17090.021488
# 3   4225.5  2009.0  3021.5  1102.5  13351.439093  13142.018791  16619.060110
# 4   4422.0  2286.5  3344.0  1090.5  13691.473846  13743.674341  17313.013681
# 5   4175.0  2175.0  3035.5  1143.5  12925.561786  13376.076264  16559.827253
# 6   4335.0  2168.0  3033.0  1155.0  13252.896722  13691.116474  16613.837906
# 7   3922.5  2239.0  3216.5  1199.5  12799.441071  14088.089615  17371.814725
# 8   4028.5  1971.5  3165.0  1071.0  13336.808324  13084.993626  17154.448901
# 9   4028.5  2166.5  3129.5  1131.0  12911.854148  13679.298956  16904.175934
# 10  4445.0  2166.0  3286.0  1166.0  13084.825592  13593.833278  17548.213058
# 11  4219.5  2197.5  3392.0  1145.5  13106.687225  13697.953187  17372.782582
# 12  3911.5  2069.0  3015.0  1078.0  12713.345962  13246.245604  16603.738187
# 13  4962.5  2589.5  3604.0  1166.5  14014.197059  14600.833529  19134.194118
#
#            S-P4  Year
# 0   7874.499701  2010
# 1   8076.527088  2011
# 2   8208.731680  2012
# 3   7940.822033  2013
# 4   7908.580330  2014
# 5   8094.724258  2015
# 6   8022.035675  2016
# 7   8207.726923  2017
# 8   7806.762363  2018
# 9   8039.368819  2019
# 10  8246.719063  2020
# 11  7979.586511  2021
# 12  7637.620742  2022
# 13  8372.507353  2023

# %%
sample = data2
for col in sample.columns[:-1]:
    plt.figure(figsize=(12, 6))
    # moving_average = sample[col].rolling(window=100).mean()
    plt.plot(pd.to_datetime(sample['Year'], format='%Y', errors='coerce'), data2[col])
    # Add labels and title
    plt.xlabel('Year')
    plt.ylabel(col)
    plt.title('trend Year and ' + col)
    plt.grid(True)
    # Show the plot
    plt.show()

# %%
sample = data2
plt.figure(figsize=(12, 6))
for col in data2.columns[:-5]:
    plt.plot(pd.to_datetime(sample['Year'], format='%Y', errors='coerce'), data2[col], label=col)
plt.xlabel('Year')
plt.title('trend Year')
plt.grid(True)
plt.legend()
plt.show()

# %%
sample = data2
plt.figure(figsize=(12, 6))
for col in sample.columns[-5:-1]:
    plt.plot(pd.to_datetime(sample['Year'], format='%Y', errors='coerce'), data2[col], label=col)
plt.xlabel('Year')
plt.title('trend Year')
plt.grid(True)
plt.legend()
plt.show()

# %%
data2[data2.columns[:-5]].describe()
# Out:
#               Q-P1         Q-P2         Q-P3         Q-P4
# count    14.000000    14.000000    14.000000    14.000000
# mean   4187.107143  2166.428571  3213.892857  1136.428571
# std     293.701260   150.306080   170.344468    38.192759
# min    3867.000000  1971.500000  3015.000000  1071.000000
# 25%    3949.000000  2072.875000  3059.000000  1109.375000
# 50%    4169.000000  2166.250000  3190.750000  1144.500000
# 75%    4307.625000  2191.875000  3313.750000  1165.250000
# max    4962.500000  2589.500000  3604.000000  1199.500000

# %%
data2[data2.columns[-5:-1]].describe()
# Out:
#                S-P1          S-P2          S-P3         S-P4
# count     14.000000     14.000000     14.000000    14.000000
# mean   13119.374444  13582.094244  17183.031585  8029.729467
# std      399.802748    412.920864    652.183333   193.654793
# min    12502.628049  13084.993626  16559.827253  7637.620742
# 25%    12832.247380  13278.703269  16690.339066  7916.640755
# 50%    13095.756409  13630.711166  17122.235194  8030.702247
# 75%    13315.830424  13696.244009  17357.114464  8179.476257
# max    14014.197059  14600.833529  19134.194118  8372.507353

# %% [markdown]
# conclusion: from analyze by ploting graph and basic statistic we see that for the number of product sale P1 is the most product that got sold but in the income we see that P3 is the most product that have the higest income from dataset
